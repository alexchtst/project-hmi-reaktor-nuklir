# %%
def check_all_project_names(
    digsilent_path,
):
    import sys
    import os

    try:
        if not os.path.exists(digsilent_path):
            raise OSError(f"{digsilent_path} does not exist")

        print(f"[INFO]: Activating project...")
        sys.path.append(rf"{digsilent_path}")
        import powerfactory as pf

        # Get PowerFactory application
        app = pf.GetApplication()
        if app is None:
            raise RuntimeError("Cannot get PowerFactory application.")

        app.ClearOutputWindow()
        app.ResetCalculation()
        print(f"[DONE]: Success activating project")
        
        user = app.GetCurrentUser()
        
        projects = user.GetContents('*.Intprj', 0)
        
        for proj in projects:
            print(proj.loc_name)

    except Exception as e:
        import traceback
        error_details = traceback.format_exc()
        error_message = f"Error occurred: {str(e)}\n\nDetails:\n{error_details}"
        print(error_message)

# %%
def run_dynamic_simulation(
    digsilent_path,
    proj_name,
    case_name,
    start_time_simulation=0,
    stop_time_simulation=100,
    step_size=0.01,
    events_config=None,
    properties_data_name={
        "ElmSym": ["m:P:bus1", "m:Q:bus1", "n:fehz:bus1"],
        "ElmTerm": ["m:fehz"],
        "ElmLne": [],
        "ElmTr2": [],
    },
    output_dir="../data"
):
    import sys
    import os
    import csv

    try:
        if not os.path.exists(digsilent_path):
            raise OSError(f"{digsilent_path} is not exist")

        sys.path.append(rf"{digsilent_path}")
        import powerfactory as pf

        app = pf.GetApplication()
        if app is None:
            raise RuntimeError("Cannot get PowerFactory application.")

        app.ClearOutputWindow()
        app.ResetCalculation()

        project = app.ActivateProject(proj_name)
        if project is None:
            raise RuntimeError(f"Cannot activate project '{proj_name}'")

        study_case = app.GetActiveStudyCase()
        if study_case is None:
            study_cases = app.GetProjectFolder(
                'study').GetContents('*.IntCase')
            for case in study_cases:
                if case.loc_name == case_name:
                    case.Activate()
                    study_case = case
                    break

            if study_case is None:
                raise RuntimeError(
                    f"Cannot find or activate study case '{case_name}'")

        comInc = app.GetFromStudyCase("ComInc")
        print(comInc)
        for attr in dir(comInc):
            try:
                value = getattr(comInc, attr)
                print(attr, "=", value)
            except:
                pass
        comSim = app.GetFromStudyCase("ComSim")

        return True, f"Success to run dynamic simulation. Rows written"

    except Exception as e:
        import traceback
        error_details = traceback.format_exc()
        error_message = f"Dynamic simulation error: {str(e)}\n\nDetails:\n{error_details}"
        print(error_message)
        return False, error_message

# %%
df_path = r"C:\Program Files\DIgSILENT\PowerFactory 2024\Python\3.10"
proj_name = "39 Bus New England System"
case_name = "1. Power Flow"

run_dynamic_simulation(
    df_path, proj_name, case_name
)
# Out:
# <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>
# AddCopy = <powerfactory.Method 'AddCopy' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# AttributeType = <class 'powerfactory.AttributeType'>
# CompileDynamicModelTypes = <powerfactory.Method 'CompileDynamicModelTypes' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# CopyData = <powerfactory.Method 'CopyData' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# CreateObject = <powerfactory.Method 'CreateObject' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# Delete = <bound method Delete of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# Energize = <powerfactory.Method 'Energize' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# Execute = <powerfactory.Method 'Execute' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetAttribute = <bound method GetAttribute of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributeDescription = <bound method GetAttributeDescription of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributeLength = <bound method GetAttributeLength of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributeShape = <bound method GetAttributeShape of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributeType = <bound method GetAttributeType of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributeUnit = <bound method GetAttributeUnit of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetAttributes = <bound method GetAttributes of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# GetChildren = <powerfactory.Method 'GetChildren' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetClassName = <powerfactory.Method 'GetClassName' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetCombinedProjectSource = <powerfactory.Method 'GetCombinedProjectSource' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetConnectedElements = <powerfactory.Method 'GetConnectedElements' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetConnectionCount = <powerfactory.Method 'GetConnectionCount' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetContents = <powerfactory.Method 'GetContents' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetContents = <powerfactory.Method 'GetContents' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetControlledNode = <powerfactory.Method 'GetControlledNode' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetCubicle = <powerfactory.Method 'GetCubicle' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetFullName = <powerfactory.Method 'GetFullName' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetImpedance = <powerfactory.Method 'GetImpedance' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetInom = <powerfactory.Method 'GetInom' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetNode = <powerfactory.Method 'GetNode' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetOperator = <powerfactory.Method 'GetOperator' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetOwner = <powerfactory.Method 'GetOwner' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetParent = <powerfactory.Method 'GetParent' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetReferences = <powerfactory.Method 'GetReferences' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetRegion = <powerfactory.Method 'GetRegion' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetSupplyingSubstations = <powerfactory.Method 'GetSupplyingSubstations' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetSupplyingTransformers = <powerfactory.Method 'GetSupplyingTransformers' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetSupplyingTrfstations = <powerfactory.Method 'GetSupplyingTrfstations' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetSystemGrounding = <powerfactory.Method 'GetSystemGrounding' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetUnom = <powerfactory.Method 'GetUnom' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# GetZeroImpedance = <powerfactory.Method 'GetZeroImpedance' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# HasAttribute = <bound method HasAttribute of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# HasReferences = <powerfactory.Method 'HasReferences' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# HasResults = <powerfactory.Method 'HasResults' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsCalcRelevant = <powerfactory.Method 'IsCalcRelevant' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsDeleted = <powerfactory.Method 'IsDeleted' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsEarthed = <powerfactory.Method 'IsEarthed' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsEnergized = <powerfactory.Method 'IsEnergized' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsHidden = <powerfactory.Method 'IsHidden' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsInFeeder = <powerfactory.Method 'IsInFeeder' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsNetworkDataFolder = <powerfactory.Method 'IsNetworkDataFolder' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsNode = <powerfactory.Method 'IsNode' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsObjectActive = <powerfactory.Method 'IsObjectActive' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsObjectModifiedByVariation = <powerfactory.Method 'IsObjectModifiedByVariation' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsOutOfService = <powerfactory.Method 'IsOutOfService' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsReducible = <powerfactory.Method 'IsReducible' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# IsShortCircuited = <powerfactory.Method 'IsShortCircuited' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# Isolate = <powerfactory.Method 'Isolate' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# Isolate = <powerfactory.Method 'Isolate' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# MarkInGraphics = <powerfactory.Method 'MarkInGraphics' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# Move = <powerfactory.Method 'Move' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# PasteCopy = <powerfactory.Method 'PasteCopy' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# PasteCopy = <powerfactory.Method 'PasteCopy' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# PurgeUnusedObjects = <powerfactory.Method 'PurgeUnusedObjects' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# ReportUnusedObjects = <powerfactory.Method 'ReportUnusedObjects' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# SearchObject = <powerfactory.Method 'SearchObject' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# SetAttribute = <bound method SetAttribute of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# SetAttributeLength = <bound method SetAttributeLength of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# SetAttributeShape = <bound method SetAttributeShape of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# SetAttributes = <bound method SetAttributes of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# ShowEditDialog = <powerfactory.Method 'ShowEditDialog' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# ShowModalSelectTree = <powerfactory.Method 'ShowModalSelectTree' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# SwitchOff = <powerfactory.Method 'SwitchOff' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# SwitchOn = <powerfactory.Method 'SwitchOn' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# WriteChangesToDb = <bound method WriteChangesToDb of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# ZeroDerivative = <powerfactory.Method 'ZeroDerivative' of <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l3>>
# __class__ = <class 'powerfactory.DataObject'>
# __delattr__ = <method-wrapper '__delattr__' of DataObject object at 0x0000014ECDCC47B0>
# __dict__ = {}
# __dir__ = <bound method __dir__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __doc__ = None
# __eq__ = <bound method __eq__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __format__ = <built-in method __format__ of DataObject object at 0x0000014ECDCC47B0>
# __ge__ = <method-wrapper '__ge__' of DataObject object at 0x0000014ECDCC47B0>
# __getattr__ = <bound method __getattr__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __getattribute__ = <method-wrapper '__getattribute__' of DataObject object at 0x0000014ECDCC47B0>
# __gt__ = <method-wrapper '__gt__' of DataObject object at 0x0000014ECDCC47B0>
# __hash__ = <bound method __hash__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __init__ = <built-in function __init__>
# __init_subclass__ = <built-in method __init_subclass__ of Boost.Python.class object at 0x0000014ECCD74E60>
# __le__ = <method-wrapper '__le__' of DataObject object at 0x0000014ECDCC47B0>
# __lt__ = <method-wrapper '__lt__' of DataObject object at 0x0000014ECDCC47B0>
# __module__ = powerfactory
# __ne__ = <bound method __ne__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __new__ = <built-in method __new__ of Boost.Python.class object at 0x00007FFC64E9D610>
# __reduce__ = <bound method <unnamed Boost.Python function> of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __reduce_ex__ = <built-in method __reduce_ex__ of DataObject object at 0x0000014ECDCC47B0>
# __repr__ = <bound method __repr__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __setattr__ = <bound method __setattr__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __sizeof__ = <built-in method __sizeof__ of DataObject object at 0x0000014ECDCC47B0>
# __str__ = <bound method __str__ of <powerfactory.DataObject <l1>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Calculation of Initial Conditions.ComInc</l1>>>
# __subclasshook__ = <built-in method __subclasshook__ of Boost.Python.class object at 0x0000014ECCD74E60>
# __weakref__ = None
# addoptions =
# advancedNewtonUpdt = 0
# allowedBusErrLv = 0.01
# allowedBusErrLv_emt = 0.01
# allowedBusErrMv = 1.0
# allowedBusErrMv_emt = 1.0
# allowedErrAllGridEq = 0.1
# alpha_emt = 0.99
# alpha_rms = 1.0
# automaticCompilation = 1
# charact = []
# chr_name =
# ciopt_sample = 0
# ckres = 0.0
# cloadSnap = 0
# clockedEventType = 0
# com_init = 1
# com_inter = 1000.0
# copt_adapt = 0
# copt_coiref = 0
# copt_fastcon = 1
# copt_lt = 2
# copt_net = 0
# copt_real = 0
# copt_reinc = 0
# copt_sim = 1
# cpHeadFold = <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase</l3>
# crndNumGen = ['Mersenne Twister']
# ctstart = 0.0
# cvoltLevHv = 66.0
# cvoltLevLv = 0.0
# cvoltLevMv = 1.0
# dat_src = MAN
# dataExtDesc = []
# dataExtUnit = []
# ddtemt_max = 1.0
# ddtgrd_max = 50.0
# disablePreciseLanding = 0
# dtemt = 0.1
# dtemt_max = 8.0
# dtgrd = 1.0
# dtgrd_max = 100.0
# dtout = 2.0
# dtout_emt = 0.2
# erreq = 1.0
# erreq_emt = 0.1
# errinc = 0.001
# errmax = 0.01
# errseq = 0.1
# errsm = 1.0
# errsm_emt = 1.0
# fdec = 2.0
# finc = 1.5
# fold_id = <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase</l3>
# for_name =
# gnrl_modby =
# gnrl_modif = 1764064009
# iReuseLdf = 0
# iSchemeStatus = 0
# i_deldirect = 0
# i_multincw = 0
# i_rndseed = 0
# i_sedirect = 1
# iac = 1
# iinftag = 0
# iopt_adapt = 0
# iopt_adaptadv = 0
# iopt_adaptreset = 1
# iopt_all = 0
# iopt_coiref = 0
# iopt_conn = 0
# iopt_dfrotx = 0
# iopt_eulmax = 2
# iopt_expref = 0
# iopt_fastchk = 1
# iopt_fastcon = 1
# iopt_fastout = 1
# iopt_fastsol = 0
# iopt_int = 1
# iopt_load = 0
# iopt_locref = 1
# iopt_lt = 2
# iopt_net = sym
# iopt_only = 0
# iopt_outofstep = 1
# iopt_partinc = 0
# iopt_real = 0
# iopt_reinc = 0
# iopt_reinf = 0
# iopt_rnd = 0
# iopt_sample = 0
# iopt_save = 0
# iopt_show = 0
# iopt_sim = rms
# iopt_simscn = 0
# iopt_solvinc = 0
# iopt_startmax = 0
# iopt_sync = 0
# iopt_vdhnm = 0
# ipolate = 1
# itrjx = 5
# itrlx = 25
# itrmx = 4
# itrmxdisc = 100
# itrmxint = 4
# itrmxmin = 100
# jacobianUpdateMode = 0
# kres = 0.001
# lastSeed = ['-']
# loadSnap = 0
# loc_name = Calculation of Initial Conditions
# mult_out = 2
# mult_out_emt = 2
# ninc = 10
# oid_ = 1611514
# order = -1000000.0
# outofstepdet = 360.0
# outputstep = 2.0
# p_event = <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Simulation Events/Fault.IntEvt</l3>
# p_resvar = <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\All calculations.ElmRes</l3>
# p_simscn = <l3>\Alex.IntUser\39 Bus New England System.IntPrj\Study Cases.IntPrjfolder\1. Power Flow.IntCase\Simulation Scan.IntScn</l3>
# pid_ = 1608005
# quasiNewton = 0
# reincEvtType = 1
# reincIter = 1
# rndNumGen = 0
# root_id = None
# rt_factor = 100.0
# rt_inter = 1000.0
# sigTypeConComp = 0
# sigbuf = 50
# snapFile =
# snapPath =
# solveInitDisc = 0
# syncperiod = 1000.0
# syncresult = 1
# systemSolvingMode = 0
# systemSolvingModeFlags = 0
# tcemt = 10.0
# tcgrd = 10000.0
# tid_ = 4294967294
# tstart = -100000.0
# tsync = 10000.0
# updateRng = 1
# (True, 'Success to run dynamic simulation. Rows written')
