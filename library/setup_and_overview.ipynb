# %%
from digsilent_pf_lib import DigsilentPowerFactoryLibrary

# %%
example_library = DigsilentPowerFactoryLibrary(
    digsilent_path=r"C:\Program Files\DIgSILENT\PowerFactory 2024 SP1\Python\3.12"
)
# Out:
# berhasil Menginisiasi power factory digsilent

# %%
status, message, result = example_library.detect_project_names()

# %%
status, message
# Out:
# (True, '[SUCCESS]: Berhasil mengambil semua case dalam project None')

# %%
result
# Out:
# ['39 Bus New England System', 'Nine-bus System', 'Sistem Bangka']

# %%
status, message = example_library.connect_digsilent_pf_project("39 Bus New England System")

# %%
message
# Out:
# '[SUCCESS]: Berhasil aktifasi dan mengganti project'

# %%
example_library.detect_study_cases()
# Out:
# (True,
#  '[SUCCESS]: Berhasil mengambil semua case dalam project 39 Bus New England System',
#  ['1. Power Flow',
#   '2.1 Simulation Fault Bus 16 Stable',
#   '2.2 Simulation Fault Bus 16 Unstable',
#   '2.3 Simulation Fault Bus 31 Stable',
#   '2.4 Simulation Fault Bus 31 Unstable',
#   '2.5 Simulation Fault Line 2-3 Stable',
#   '2.6 Simulation Fault Line 2-3 Unstable',
#   '3. Small Signal Analysis (Eigenvalues)',
#   '4. EMT Simulation Fault Bus 03'])
